# %%
import pandas as pd

# %%
news_df = pd.read_excel('ura_new.xlsx')
news_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'👍'}>,
#         <AxesSubplot:title={'center':'👎'}>,
#         <AxesSubplot:title={'center':'😁'}>],
#        [<AxesSubplot:title={'center':'😱'}>,
#         <AxesSubplot:title={'center':'🔥'}>,
#         <AxesSubplot:title={'center':'😢'}>],
#        [<AxesSubplot:title={'center':'❤'}>,
#         <AxesSubplot:title={'center':'🤬'}>,
#         <AxesSubplot:title={'center':'👏'}>]], dtype=object)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128078 (\N{THUMBS DOWN SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
news_df = pd.read_excel('rt_new.xlsx')
news_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'👍'}>,
#         <AxesSubplot:title={'center':'👎'}>,
#         <AxesSubplot:title={'center':'😁'}>],
#        [<AxesSubplot:title={'center':'😱'}>,
#         <AxesSubplot:title={'center':'🔥'}>,
#         <AxesSubplot:title={'center':'😢'}>],
#        [<AxesSubplot:title={'center':'❤'}>,
#         <AxesSubplot:title={'center':'🤬'}>,
#         <AxesSubplot:title={'center':'👏'}>]], dtype=object)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128078 (\N{THUMBS DOWN SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
news_df = pd.read_excel('readovka_new.xlsx')
news_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'👍'}>,
#         <AxesSubplot:title={'center':'👎'}>,
#         <AxesSubplot:title={'center':'😁'}>],
#        [<AxesSubplot:title={'center':'😱'}>,
#         <AxesSubplot:title={'center':'🔥'}>,
#         <AxesSubplot:title={'center':'😢'}>],
#        [<AxesSubplot:title={'center':'❤'}>,
#         <AxesSubplot:title={'center':'🤬'}>,
#         <AxesSubplot:title={'center':'👏'}>]], dtype=object)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128078 (\N{THUMBS DOWN SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
news_df = pd.read_excel('cut_the_crap_new.xlsx')
news_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'👍'}>,
#         <AxesSubplot:title={'center':'👎'}>,
#         <AxesSubplot:title={'center':'😁'}>],
#        [<AxesSubplot:title={'center':'😱'}>,
#         <AxesSubplot:title={'center':'🔥'}>,
#         <AxesSubplot:title={'center':'😢'}>],
#        [<AxesSubplot:title={'center':'❤'}>,
#         <AxesSubplot:title={'center':'🤬'}>,
#         <AxesSubplot:title={'center':'👏'}>]], dtype=object)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Qwerty\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128078 (\N{THUMBS DOWN SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
